# %%
from PIL import Image, ImageDraw
import argparse
import io

from google.cloud import vision
from google.cloud.vision import types

# %%
raw_invoice_image_path = 'invoice.jpg'
raw_invoice_image = Image.open(raw_invoice_image_path)
raw_invoice_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=585x741 at 0x7F55445F6F90>

# %%
def addRect(draw, point1_X, point1_Y, point2_X, point2_Y,fill, width):
    draw.line((point1_X,point1_Y, point2_X, point1_Y), fill=fill, width=width)
    draw.line((point2_X,point1_Y, point2_X, point2_Y), fill=fill, width=width)
    draw.line((point2_X,point2_Y, point1_X, point2_Y), fill=fill, width=width)
    draw.line((point1_X,point2_Y, point1_X, point1_Y), fill=fill, width=width)

manual_invoice_image = Image.open(raw_invoice_image_path)
draw = ImageDraw.Draw(manual_invoice_image)
addRect(draw, 100,200, 400,300, fill=(255,0,0), width=3)
addRect(draw, 100,500, 400,600, fill=(255,255,0), width=3)
manual_invoice_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=585x741 at 0x7F554451C050>

# %%
def google_detect_document(path):
    """Detects document features in an image."""
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = types.Image(content=content)

    response = client.document_text_detection(image=image)
    document = response.full_text_annotation

    for page in document.pages:
        for block in page.blocks:
            block_words = []
            for paragraph in block.paragraphs:
                block_words.extend(paragraph.words)

            block_symbols = []
            for word in block_words:
                block_symbols.extend(word.symbols)

            block_text = ''
            for symbol in block_symbols:
                block_text = block_text + symbol.text

#            print('Block Content: {}'.format(block_text))
#            print('Block Bounds:\n {}'.format(block.bounding_box))
    return document

# %%
google_detection = google_detect_document(raw_invoice_image_path)

# %%
def print_detected(document):
    for page in document.pages:
        for block in page.blocks:
            block_words = []
            for paragraph in block.paragraphs:
                block_words.extend(paragraph.words)

            block_symbols = []
            for word in block_words:
                block_symbols.extend(word.symbols)

            block_text = ''
            for symbol in block_symbols:
                block_text = block_text + symbol.text

            print('Block Content: {}'.format(block_text))
            print('Block Bounds:\n {}'.format(block.bounding_box))

print_detected(google_detection)
# Out:
# Block Content: YourCompanyName
# Block Bounds:
#  vertices {
#   x: 127
#   y: 37
# }
# vertices {
#   x: 302
#   y: 37
# }
# vertices {
#   x: 302
#   y: 53
# }
# vertices {
#   x: 127
#   y: 53
# }
#
# Block Content: INVOICE
# Block Bounds:
#  vertices {
#   x: 399
#   y: 30
# }
# vertices {
#   x: 530
#   y: 30
# }
# vertices {
#   x: 530
#   y: 49
# }
# vertices {
#   x: 399
#   y: 49
# }
#
# Block Content: StreetAddressCity,STZIPCodePhoneNumber,WebAddress,etc
# Block Bounds:
#  vertices {
#   x: 124
#   y: 64
# }
# vertices {
#   x: 271
#   y: 64
# }
# vertices {
#   x: 271
#   y: 98
# }
# vertices {
#   x: 124
#   y: 98
# }
#
# Block Content: DATE:November17,2006INVOICE#INV1000
# Block Bounds:
#  vertices {
#   x: 386
#   y: 75
# }
# vertices {
#   x: 528
#   y: 75
# }
# vertices {
#   x: 528
#   y: 96
# }
# vertices {
#   x: 386
#   y: 96
# }
#
# Block Content: BillTo:C1007ABCCompany123BigForestValleyOttawa,OnZ12345Canada
# Block Bounds:
#  vertices {
#   x: 73
#   y: 144
# }
# vertices {
#   x: 216
#   y: 144
# }
# vertices {
#   x: 216
#   y: 203
# }
# vertices {
#   x: 73
#   y: 203
# }
#
# Block Content: ShipTo:SHName1SHAddress1SHCityState1SHZ12345USA
# Block Bounds:
#  vertices {
#   x: 370
#   y: 145
# }
# vertices {
#   x: 485
#   y: 145
# }
# vertices {
#   x: 485
#   y: 203
# }
# vertices {
#   x: 370
#   y: 203
# }
#
# Block Content: P.0.o20081200s
# Block Bounds:
#  vertices {
#   x: 61
#   y: 240
# }
# vertices {
#   x: 116
#   y: 240
# }
# vertices {
#   x: 116
#   y: 275
# }
# vertices {
#   x: 61
#   y: 275
# }
#
# Block Content: SalesRep.NameShipDateShipViaTermsSales111172006UPS7Net
# Block Bounds:
#  vertices {
#   x: 143
#   y: 242
# }
# vertices {
#   x: 420
#   y: 242
# }
# vertices {
#   x: 420
#   y: 275
# }
# vertices {
#   x: 143
#   y: 275
# }
#
# Block Content: DueDateO
# Block Bounds:
#  vertices {
#   x: 469
#   y: 244
# }
# vertices {
#   x: 508
#   y: 244
# }
# vertices {
#   x: 508
#   y: 275
# }
# vertices {
#   x: 469
#   y: 275
# }
#
# Block Content: UnitPrice
# Block Bounds:
#  vertices {
#   x: 385
#   y: 300
# }
# vertices {
#   x: 429
#   y: 300
# }
# vertices {
#   x: 429
#   y: 309
# }
# vertices {
#   x: 385
#   y: 309
# }
#
# Block Content: ProductIDDescriptionP1003MotorolaE815P1000Nokia3220
# Block Bounds:
#  vertices {
#   x: 58
#   y: 300
# }
# vertices {
#   x: 236
#   y: 300
# }
# vertices {
#   x: 236
#   y: 348
# }
# vertices {
#   x: 58
#   y: 348
# }
#
# Block Content: Quantity10
# Block Bounds:
#  vertices {
#   x: 315
#   y: 300
# }
# vertices {
#   x: 354
#   y: 300
# }
# vertices {
#   x: 354
#   y: 328
# }
# vertices {
#   x: 315
#   y: 328
# }
#
# Block Content: LineTotal4,200.00
# Block Bounds:
#  vertices {
#   x: 467
#   y: 302
# }
# vertices {
#   x: 525
#   y: 302
# }
# vertices {
#   x: 525
#   y: 330
# }
# vertices {
#   x: 467
#   y: 330
# }
#
# Block Content: 420.00
# Block Bounds:
#  vertices {
#   x: 410
#   y: 320
# }
# vertices {
#   x: 437
#   y: 321
# }
# vertices {
#   x: 437
#   y: 329
# }
# vertices {
#   x: 410
#   y: 328
# }
#
# Block Content: 12
# Block Bounds:
#  vertices {
#   x: 345
#   y: 338
# }
# vertices {
#   x: 354
#   y: 338
# }
# vertices {
#   x: 354
#   y: 347
# }
# vertices {
#   x: 345
#   y: 347
# }
#
# Block Content: 199.99
# Block Bounds:
#  vertices {
#   x: 411
#   y: 339
# }
# vertices {
#   x: 438
#   y: 339
# }
# vertices {
#   x: 438
#   y: 348
# }
# vertices {
#   x: 411
#   y: 348
# }
#
# Block Content: 2399.88
# Block Bounds:
#  vertices {
#   x: 490
#   y: 341
# }
# vertices {
#   x: 525
#   y: 339
# }
# vertices {
#   x: 525
#   y: 347
# }
# vertices {
#   x: 490
#   y: 349
# }
#
# Block Content: P1004
# Block Bounds:
#  vertices {
#   x: 59
#   y: 358
# }
# vertices {
#   x: 85
#   y: 358
# }
# vertices {
#   x: 85
#   y: 367
# }
# vertices {
#   x: 59
#   y: 367
# }
#
# Block Content: Non-taxableitem
# Block Bounds:
#  vertices {
#   x: 123
#   y: 359
# }
# vertices {
#   x: 201
#   y: 359
# }
# vertices {
#   x: 201
#   y: 367
# }
# vertices {
#   x: 123
#   y: 367
# }
#
# Block Content: 200.00
# Block Bounds:
#  vertices {
#   x: 410
#   y: 359
# }
# vertices {
#   x: 437
#   y: 359
# }
# vertices {
#   x: 437
#   y: 367
# }
# vertices {
#   x: 410
#   y: 367
# }
#
# Block Content: 100000
# Block Bounds:
#  vertices {
#   x: 488
#   y: 360
# }
# vertices {
#   x: 525
#   y: 358
# }
# vertices {
#   x: 525
#   y: 367
# }
# vertices {
#   x: 488
#   y: 369
# }
#
# Block Content: P1002
# Block Bounds:
#  vertices {
#   x: 58
#   y: 378
# }
# vertices {
#   x: 83
#   y: 379
# }
# vertices {
#   x: 83
#   y: 387
# }
# vertices {
#   x: 58
#   y: 386
# }
#
# Block Content: Itisaservice
# Block Bounds:
#  vertices {
#   x: 124
#   y: 378
# }
# vertices {
#   x: 181
#   y: 378
# }
# vertices {
#   x: 181
#   y: 386
# }
# vertices {
#   x: 124
#   y: 386
# }
#
# Block Content: 3.2
# Block Bounds:
#  vertices {
#   x: 343
#   y: 378
# }
# vertices {
#   x: 354
#   y: 378
# }
# vertices {
#   x: 354
#   y: 386
# }
# vertices {
#   x: 343
#   y: 386
# }
#
# Block Content: 255.52
# Block Bounds:
#  vertices {
#   x: 410
#   y: 379
# }
# vertices {
#   x: 438
#   y: 379
# }
# vertices {
#   x: 438
#   y: 386
# }
# vertices {
#   x: 410
#   y: 386
# }
#
# Block Content: 817.66
# Block Bounds:
#  vertices {
#   x: 498
#   y: 379
# }
# vertices {
#   x: 527
#   y: 379
# }
# vertices {
#   x: 527
#   y: 387
# }
# vertices {
#   x: 498
#   y: 387
# }
#
# Block Content: P1006
# Block Bounds:
#  vertices {
#   x: 59
#   y: 396
# }
# vertices {
#   x: 85
#   y: 396
# }
# vertices {
#   x: 85
#   y: 405
# }
# vertices {
#   x: 59
#   y: 405
# }
#
# Block Content: MotorolaVSRazrBlack
# Block Bounds:
#  vertices {
#   x: 123
#   y: 396
# }
# vertices {
#   x: 226
#   y: 396
# }
# vertices {
#   x: 226
#   y: 405
# }
# vertices {
#   x: 123
#   y: 405
# }
#
# Block Content: 10
# Block Bounds:
#  vertices {
#   x: 345
#   y: 396
# }
# vertices {
#   x: 354
#   y: 396
# }
# vertices {
#   x: 354
#   y: 405
# }
# vertices {
#   x: 345
#   y: 405
# }
#
# Block Content: 500.00
# Block Bounds:
#  vertices {
#   x: 411
#   y: 396
# }
# vertices {
#   x: 438
#   y: 396
# }
# vertices {
#   x: 438
#   y: 406
# }
# vertices {
#   x: 411
#   y: 406
# }
#
# Block Content: 500000
# Block Bounds:
#  vertices {
#   x: 489
#   y: 397
# }
# vertices {
#   x: 525
#   y: 395
# }
# vertices {
#   x: 525
#   y: 405
# }
# vertices {
#   x: 489
#   y: 407
# }
#
# Block Content: 13,417.54
# Block Bounds:
#  vertices {
#   x: 485
#   y: 550
# }
# vertices {
#   x: 526
#   y: 550
# }
# vertices {
#   x: 526
#   y: 559
# }
# vertices {
#   x: 485
#   y: 559
# }
#
# Block Content: SUBTOTALPST6.50%
# Block Bounds:
#  vertices {
#   x: 349
#   y: 551
# }
# vertices {
#   x: 435
#   y: 551
# }
# vertices {
#   x: 435
#   y: 579
# }
# vertices {
#   x: 349
#   y: 579
# }
#
# Block Content: Notes:
# Block Bounds:
#  vertices {
#   x: 57
#   y: 571
# }
# vertices {
#   x: 85
#   y: 571
# }
# vertices {
#   x: 85
#   y: 579
# }
# vertices {
#   x: 57
#   y: 579
# }
#
# Block Content: 807.14
# Block Bounds:
#  vertices {
#   x: 499
#   y: 571
# }
# vertices {
#   x: 526
#   y: 571
# }
# vertices {
#   x: 526
#   y: 579
# }
# vertices {
#   x: 499
#   y: 579
# }
#
# Block Content: GST
# Block Bounds:
#  vertices {
#   x: 347
#   y: 590
# }
# vertices {
#   x: 368
#   y: 590
# }
# vertices {
#   x: 368
#   y: 598
# }
# vertices {
#   x: 347
#   y: 598
# }
#
# Block Content: 3.20%
# Block Bounds:
#  vertices {
#   x: 407
#   y: 590
# }
# vertices {
#   x: 433
#   y: 590
# }
# vertices {
#   x: 433
#   y: 598
# }
# vertices {
#   x: 407
#   y: 598
# }
#
# Block Content: 397.36
# Block Bounds:
#  vertices {
#   x: 498
#   y: 590
# }
# vertices {
#   x: 527
#   y: 590
# }
# vertices {
#   x: 527
#   y: 597
# }
# vertices {
#   x: 498
#   y: 597
# }
#
# Block Content: H
# Block Bounds:
#  vertices {
#   x: 529
#   y: 600
# }
# vertices {
#   x: 531
#   y: 600
# }
# vertices {
#   x: 530
#   y: 609
# }
# vertices {
#   x: 528
#   y: 609
# }
#
# Block Content: SHIPPING&HANDLING
# Block Bounds:
#  vertices {
#   x: 328
#   y: 608
# }
# vertices {
#   x: 437
#   y: 608
# }
# vertices {
#   x: 437
#   y: 617
# }
# vertices {
#   x: 328
#   y: 617
# }
#
# Block Content: TOTAL
# Block Bounds:
#  vertices {
#   x: 404
#   y: 627
# }
# vertices {
#   x: 436
#   y: 627
# }
# vertices {
#   x: 436
#   y: 635
# }
# vertices {
#   x: 404
#   y: 635
# }
#
# Block Content: 14,622.04
# Block Bounds:
#  vertices {
#   x: 485
#   y: 628
# }
# vertices {
#   x: 527
#   y: 629
# }
# vertices {
#   x: 527
#   y: 636
# }
# vertices {
#   x: 485
#   y: 635
# }
#
# Block Content: PAIDTOTALDUE
# Block Bounds:
#  vertices {
#   x: 381
#   y: 645
# }
# vertices {
#   x: 437
#   y: 645
# }
# vertices {
#   x: 437
#   y: 671
# }
# vertices {
#   x: 381
#   y: 671
# }
#
# Block Content: 14,622.04
# Block Bounds:
#  vertices {
#   x: 485
#   y: 664
# }
# vertices {
#   x: 525
#   y: 664
# }
# vertices {
#   x: 525
#   y: 676
# }
# vertices {
#   x: 485
#   y: 676
# }
#
# Block Content: THANKYOUFORYOURBUSINESS
# Block Bounds:
#  vertices {
#   x: 210
#   y: 693
# }
# vertices {
#   x: 372
#   y: 693
# }
# vertices {
#   x: 372
#   y: 703
# }
# vertices {
#   x: 210
#   y: 703
# }

# %%
def collect_text_areas(document):
    areas = []
    for page in document.pages:
        for block in page.blocks:
            block_words = []
            for paragraph in block.paragraphs:
                block_words.extend(paragraph.words)

            block_symbols = []
            for word in block_words:
                block_symbols.extend(word.symbols)

            block_text = ''
            for symbol in block_symbols:
                block_text = block_text + symbol.text

            area = {}
            area['text'] = block_text
            area['bounds'] = block.bounding_box
            areas.append(area)
    return areas

text_areas = collect_text_areas(google_detection)
text_areas[0]
# Out:
# {'bounds': vertices {
#    x: 127
#    y: 37
#  }
#  vertices {
#    x: 302
#    y: 37
#  }
#  vertices {
#    x: 302
#    y: 53
#  }
#  vertices {
#    x: 127
#    y: 53
#  }, 'text': u'YourCompanyName'}

# %%
def drawBoxes(path, areas):
    low_threshold_len = 5
    high_threshold_len = 20
